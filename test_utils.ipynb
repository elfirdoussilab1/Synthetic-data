# %%
import numpy as np

# %%
n = 5
n//2
# Out:
# 2

# %%
phi = .7
rho = .1
eps = .2
 
n = 2000
m = 3000
p = 500
sigma = .7
 
gamma = 1e1
 
N = n + m
pi = n / N
eta = p / N
 
alpha = phi * (1 - eps) + rho * eps
 
 
delta = 0
 
for i in range(100):
    delta = eta / ( gamma + pi / (1 + delta) + alpha * (1-pi) * sigma**2 / (1 + alpha * sigma**2 * delta) )
    print(i, ':', delta)
# Out:
# 0 : 0.009460272531531089
# 1 : 0.009464038154361365
# 2 : 0.00946403964088187
# 3 : 0.00946403964146869
# 4 : 0.00946403964146892
# 5 : 0.00946403964146892
# 6 : 0.00946403964146892
# 7 : 0.00946403964146892
# 8 : 0.00946403964146892
# 9 : 0.00946403964146892
# 10 : 0.00946403964146892
# 11 : 0.00946403964146892
# 12 : 0.00946403964146892
# 13 : 0.00946403964146892
# 14 : 0.00946403964146892
# 15 : 0.00946403964146892
# 16 : 0.00946403964146892
# 17 : 0.00946403964146892
# 18 : 0.00946403964146892
# 19 : 0.00946403964146892
# 20 : 0.00946403964146892
# 21 : 0.00946403964146892
# 22 : 0.00946403964146892
# 23 : 0.00946403964146892
# 24 : 0.00946403964146892
# 25 : 0.00946403964146892
# 26 : 0.00946403964146892
# 27 : 0.00946403964146892
# 28 : 0.00946403964146892
# 29 : 0.00946403964146892
# 30 : 0.00946403964146892
# 31 : 0.00946403964146892
# 32 : 0.00946403964146892
# 33 : 0.00946403964146892
# 34 : 0.00946403964146892
# 35 : 0.00946403964146892
# 36 : 0.00946403964146892
# 37 : 0.00946403964146892
# 38 : 0.00946403964146892
# 39 : 0.00946403964146892
# 40 : 0.00946403964146892
# 41 : 0.00946403964146892
# 42 : 0.00946403964146892
# 43 : 0.00946403964146892
# 44 : 0.00946403964146892
# 45 : 0.00946403964146892
# 46 : 0.00946403964146892
# 47 : 0.00946403964146892
# 48 : 0.00946403964146892
# 49 : 0.00946403964146892
# 50 : 0.00946403964146892
# 51 : 0.00946403964146892
# 52 : 0.00946403964146892
# 53 : 0.00946403964146892
# 54 : 0.00946403964146892
# 55 : 0.00946403964146892
# 56 : 0.00946403964146892
# 57 : 0.00946403964146892
# 58 : 0.00946403964146892
# 59 : 0.00946403964146892
# 60 : 0.00946403964146892
# 61 : 0.00946403964146892
# 62 : 0.00946403964146892
# 63 : 0.00946403964146892
# 64 : 0.00946403964146892
# 65 : 0.00946403964146892
# 66 : 0.00946403964146892
# 67 : 0.00946403964146892
# 68 : 0.00946403964146892
# 69 : 0.00946403964146892
# 70 : 0.00946403964146892
# 71 : 0.00946403964146892
# 72 : 0.00946403964146892
# 73 : 0.00946403964146892
# 74 : 0.00946403964146892
# 75 : 0.00946403964146892
# 76 : 0.00946403964146892
# 77 : 0.00946403964146892
# 78 : 0.00946403964146892
# 79 : 0.00946403964146892
# 80 : 0.00946403964146892
# 81 : 0.00946403964146892
# 82 : 0.00946403964146892
# 83 : 0.00946403964146892
# 84 : 0.00946403964146892
# 85 : 0.00946403964146892
# 86 : 0.00946403964146892
# 87 : 0.00946403964146892
# 88 : 0.00946403964146892
# 89 : 0.00946403964146892
# 90 : 0.00946403964146892
# 91 : 0.00946403964146892
# 92 : 0.00946403964146892
# 93 : 0.00946403964146892
# 94 : 0.00946403964146892
# 95 : 0.00946403964146892
# 96 : 0.00946403964146892
# 97 : 0.00946403964146892
# 98 : 0.00946403964146892
# 99 : 0.00946403964146892

# %%
from rmt_results import *

# %%
x = Delta(n, m, p, sigma, eps, rho, phi, gamma)
x
# Out:
# 0.00946403964146892

# %%
a = alpha * gamma * sigma**2
b = gamma + alpha * (1 + gamma - eta) * sigma**2
c = gamma + pi - eta + alpha  * (1 - pi - eta)* sigma**2
d = - eta

# %%
a = 1
b = 3
c = 3
d = 1

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 3
# 3
# 1

# %%
x = solution(a, b, c, d)
x
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 x = solution(a, b, c, d)
#       2 x
#
# File ~/Desktop/Research/TII/Synthetic-data/rmt_results.py:9, in solution(a, b, c, d)
#       8 def solution(a, b, c, d):
# ----> 9     s = -(-3*c/a + b**2/a**2)/(3*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a)
#      10     return s
#
# ZeroDivisionError: float division by zero

# %%
import sympy as sp
 
# Define the variable
x = sp.symbols('x')
 
# Define the coefficients of the polynomial
a, b, c, d = sp.symbols('a b c d')
 
# Define the polynomial equation
polynomial = a*x**3 + b*x**2 + c*x + d
 
# To find the roots, we need to solve the equation polynomial = 0
roots = sp.solve(polynomial, x)
 
# Display the roots
print(roots)
# Out:
# [-(-3*c/a + b**2/a**2)/(3*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a), -(-3*c/a + b**2/a**2)/(3*(-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a), -(-3*c/a + b**2/a**2)/(3*(-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a)]

# %%
-(-3*c/a + b**2/a**2)/(3*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a)

# %%
roots[0]
# Out:
# -(-3*c/a + b**2/a**2)/(3*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a)

# %%
roots[1]
# Out:
# -(-3*c/a + b**2/a**2)/(3*(-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a)

# %%
roots[2]
# Out:
# -(-3*c/a + b**2/a**2)/(3*(-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)) - (-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*c/a + b**2/a**2)**3 + (27*d/a - 9*b*c/a**2 + 2*b**3/a**3)**2)/2 + 27*d/(2*a) - 9*b*c/(2*a**2) + b**3/a**3)**(1/3)/3 - b/(3*a)
